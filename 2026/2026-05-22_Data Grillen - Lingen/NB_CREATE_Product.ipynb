# %% [markdown]
# ## Query source LH, save to target LH + adjust to semantic model
# This notebook queries the source lakehouse based on a defined SQL query. After that, it saves the result set to the target lakehouse.
#
# Next, it uses Semantic Link Labs to add the resulting table from the target lakehouse to the defined semantic model.

# %%
# %pip install semantic-link-labs
import sempy_labs as labs
# Out:
# StatementMeta(, ec313d5d-820e-498d-af24-80f26ab0c732, 8, Finished, Available, Finished, False)
# Collecting semantic-link-labs
#   Downloading semantic_link_labs-0.15.1-py3-none-any.whl.metadata (29 kB)
# Collecting semantic-link-sempy>=0.14.1 (from semantic-link-labs)
#   Downloading semantic_link_sempy-0.14.1-py3-none-any.whl.metadata (21 kB)
# Collecting anytree (from semantic-link-labs)
#   Downloading anytree-2.13.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting polib (from semantic-link-labs)
#   Downloading polib-1.2.0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting jsonpath_ng (from semantic-link-labs)
#   Downloading jsonpath_ng-1.8.0-py3-none-any.whl.metadata (18 kB)
# Collecting anywidget (from semantic-link-labs)
#   Downloading anywidget-0.11.0-py3-none-any.whl.metadata (8.9 kB)
# Collecting sqlglot (from semantic-link-labs)
#   Downloading sqlglot-30.8.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: clr_loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (0.2.5)
# Collecting fabric-analytics-sdk<1.0.0,>=0.0.3 (from semantic-link-sempy>=0.14.1->semantic-link-labs)
#   Downloading fabric_analytics_sdk-0.0.3.post8-py3-none-any.whl.metadata (14 kB)
# Collecting fabric-analytics-notebook-plugin<1.0.0,>=0.0.3 (from semantic-link-sempy>=0.14.1->semantic-link-labs)
#   Downloading fabric_analytics_notebook_plugin-0.0.3.post8-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (0.20.1)
# Requirement already satisfied: azure-storage-blob>=12.18.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (12.22.0)
# Requirement already satisfied: azure-core>=1.29.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (1.30.2)
# Collecting azure-keyvault-secrets>=4.7.0 (from semantic-link-sempy>=0.14.1->semantic-link-labs)
#   Downloading azure_keyvault_secrets-4.11.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: azure-storage-file-datalake>=12.12.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (12.16.0)
# Requirement already satisfied: ipywidgets>=8.0.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (8.1.2)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (14.0.2)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (3.0.1)
# Requirement already satisfied: scikit_learn<1.8.0,>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (1.2.2)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (4.65.0)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (13.3.5)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (2023.10.3)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (2.1.4)
# Requirement already satisfied: pyjwt>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (2.4.0)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (3.5.1.5.4.20240407)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (2.31.0)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (3.9.3)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (8.20.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.1->semantic-link-labs) (8.2.3)
# Collecting psygnal>=0.8.1 (from anywidget->semantic-link-labs)
#   Downloading psygnal-0.15.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from anywidget->semantic-link-labs) (4.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.1->semantic-link-labs) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.1->semantic-link-labs) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.1->semantic-link-labs) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.1->semantic-link-labs) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.1->semantic-link-labs) (1.9.3)
# Requirement already satisfied: six>=1.11.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-core>=1.29.4->semantic-link-sempy>=0.14.1->semantic-link-labs) (1.16.0)
# Requirement already satisfied: isodate>=0.6.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-keyvault-secrets>=4.7.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (0.6.1)
# Collecting azure-core>=1.29.4 (from semantic-link-sempy>=0.14.1->semantic-link-labs)
#   Downloading azure_core-1.41.0-py3-none-any.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=2.1.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-storage-blob>=12.18.3->semantic-link-sempy>=0.14.1->semantic-link-labs) (42.0.2)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from clr_loader>=0.2.5->semantic-link-sempy>=0.14.1->semantic-link-labs) (1.16.0)
# Requirement already satisfied: psutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.1->semantic-link-labs) (5.9.0)
# Requirement already satisfied: azure-identity in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.1->semantic-link-labs) (1.15.0)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (2.15.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (4.8.0)
# Requirement already satisfied: comm>=0.1.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=8.0.7->semantic-link-sempy>=0.14.1->semantic-link-labs) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=8.0.7->semantic-link-sempy>=0.14.1->semantic-link-labs) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=8.0.7->semantic-link-sempy>=0.14.1->semantic-link-labs) (3.0.10)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy>=0.14.1->semantic-link-labs) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy>=0.14.1->semantic-link-labs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy>=0.14.1->semantic-link-labs) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy>=0.14.1->semantic-link-labs) (2023.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyspark>=3.4.1->semantic-link-sempy>=0.14.1->semantic-link-labs) (0.10.9.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.14.1->semantic-link-labs) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy>=0.14.1->semantic-link-labs) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy>=0.14.1->semantic-link-labs) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy>=0.14.1->semantic-link-labs) (2.2.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.13->clr_loader>=0.2.5->semantic-link-sempy>=0.14.1->semantic-link-labs) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=13.3.5->semantic-link-sempy>=0.14.1->semantic-link-labs) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (0.2.5)
# Requirement already satisfied: msal<2.0.0,>=1.24.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.1->semantic-link-labs) (1.25.0)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.1->semantic-link-labs) (1.0.0)
# Requirement already satisfied: executing in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (0.8.3)
# Requirement already satisfied: asttokens in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (2.0.5)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.14.1->semantic-link-labs) (0.2.2)
# Requirement already satisfied: portalocker<3,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.1->semantic-link-labs) (2.3.0)
# Downloading semantic_link_labs-0.15.1-py3-none-any.whl (973 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.4/973.4 kB 85.9 MB/s eta 0:00:00
# Downloading semantic_link_sempy-0.14.1-py3-none-any.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 142.9 MB/s eta 0:00:00
# Downloading anytree-2.13.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 15.7 MB/s eta 0:00:00
# Downloading anywidget-0.11.0-py3-none-any.whl (317 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.3/317.3 kB 81.1 MB/s eta 0:00:00
# Downloading jsonpath_ng-1.8.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 25.3 MB/s eta 0:00:00
# Downloading polib-1.2.0-py2.py3-none-any.whl (20 kB)
# Downloading sqlglot-30.8.0-py3-none-any.whl (687 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 94.9 MB/s eta 0:00:00
# Downloading azure_keyvault_secrets-4.11.0-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 34.5 MB/s eta 0:00:00
# Downloading azure_core-1.41.0-py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 65.1 MB/s eta 0:00:00
# Downloading fabric_analytics_notebook_plugin-0.0.3.post8-py3-none-any.whl (24 kB)
# Downloading fabric_analytics_sdk-0.0.3.post8-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 14.5 MB/s eta 0:00:00
# Downloading psygnal-0.15.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (855 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.0/856.0 kB 98.2 MB/s eta 0:00:00
# Installing collected packages: polib, jsonpath_ng, sqlglot, psygnal, anytree, azure-core, azure-keyvault-secrets, anywidget, fabric-analytics-sdk, fabric-analytics-notebook-plugin, semantic-link-sempy, semantic-link-labs
#   Attempting uninstall: azure-core
#     Found existing installation: azure-core 1.30.2
#     Not uninstalling azure-core at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-dd902bed-4a1b-42c2-8824-a229cbc0d771
#     Can't uninstall 'azure-core'. No files were found to uninstall.
#   Attempting uninstall: semantic-link-sempy
#     Found existing installation: semantic-link-sempy 0.11.0
#     Not uninstalling semantic-link-sempy at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-dd902bed-4a1b-42c2-8824-a229cbc0d771
#     Can't uninstall 'semantic-link-sempy'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fsspec-wrapper 0.1.15 requires PyJWT>=2.6.0, but you have pyjwt 2.4.0 which is incompatible.
# Successfully installed anytree-2.13.0 anywidget-0.11.0 azure-core-1.41.0 azure-keyvault-secrets-4.11.0 fabric-analytics-notebook-plugin-0.0.3.post8 fabric-analytics-sdk-0.0.3.post8 jsonpath_ng-1.8.0 polib-1.2.0 psygnal-0.15.1 semantic-link-labs-0.15.1 semantic-link-sempy-0.14.1 sqlglot-30.8.0
#
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %%
# Define source and target lakehouses (schemas/databases)
source_lakehouse = "LH_STORE_Silver"
target_lakehouse = "LH_STORE_Gold"
# Out:
# StatementMeta(, ec313d5d-820e-498d-af24-80f26ab0c732, 10, Finished, Available, Finished, False)

# %% [markdown]
# #### Create table in destination lakehouse

# %%
# Define source table and target table names
source_table = "product"
target_table = "product"  # new table in Gold to save results
# Out:
# StatementMeta(, ec313d5d-820e-498d-af24-80f26ab0c732, 11, Finished, Available, Finished, False)

# %%
sql_query = f"""
SELECT 
    ProductKey, 
    EnglishProductName AS ProductName, 
    EnglishDescription AS Description, 
    Color
FROM {source_lakehouse}.{source_table}
"""

# Run the SQL query and get a DataFrame
df = spark.sql(sql_query)

# Show first 5 rows of the resulting DataFrame
#df.show(5)

display(df.limit(5))
# Out:
# StatementMeta(, , -1, Cancelled, , Cancelled, True)

# %%
# Write the DataFrame as a new table in the target lakehouse
df.write.mode("overwrite").saveAsTable(f"{target_lakehouse}.{target_table}")

print(f"✅ Saved filtered data to table '{target_table}' in lakehouse '{target_lakehouse}'")
# Out:
# StatementMeta(, 95a23016-4a52-40eb-9fff-fdec2eda9eab, 3, Finished, Available, Finished, False)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Write the DataFrame as a new table in the target lakehouse
# ----> 2 df.write.mode("overwrite").saveAsTable(f"{target_lakehouse}.{target_table}")
#       4 print(f"✅ Saved filtered data to table '{target_table}' in lakehouse '{target_lakehouse}'")
#
# NameError: name 'df' is not defined

# %% [markdown]
# #### Update Semantic Model

# %%
semanticmodel_name = "Live Demo Data Grillen"
# Out:
# StatementMeta(, ec313d5d-820e-498d-af24-80f26ab0c732, 14, Finished, Available, Finished, False)

# %%
labs.directlake.add_table_to_direct_lake_semantic_model(
    dataset= semanticmodel_name,
    table_name= target_table, # reusing the target table name, as the gold lakehouse should already be self explanatory
    lakehouse_table_name= target_table,
    refresh= False,
    workspace= None, # if not specified, will be the same workspace as the notebook runs
    columns= None
)
# Out:
# StatementMeta(, ec313d5d-820e-498d-af24-80f26ab0c732, 15, Finished, Available, Finished, False)
# 🟢 The 'product' table has been added to the 'Live Demo Data Grillen' semantic model within the 'Reaching maximum automation' workspace.
# ---------------------------------------------------------------------------
# ArgumentException                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 labs.directlake.add_table_to_direct_lake_semantic_model(
#       2     dataset= semanticmodel_name,
#       3     table_name= target_table, # reusing the target table name, as the gold lakehouse should already be self explanatory
#       4     lakehouse_table_name= target_table,
#       5     refresh= False,
#       6     workspace= None, # if not specified, will be the same workspace as the notebook runs
#       7     columns= None
#       8 )
#
# File /nfs4/pyenv-dd902bed-4a1b-42c2-8824-a229cbc0d771/lib/python3.11/site-packages/sempy/_utils/_log.py:370, in mds_log.<locals>.get_wrapper.<locals>.log_decorator_wrapper(*args, **kwargs)
#     367 start_time = time.perf_counter()
#     369 try:
# --> 370     result = func(*args, **kwargs)
#     372     # The invocation for get_message_dict moves after the function
#     373     # so it can access the state after the method call
#     374     message.update(extractor.get_completion_message_dict(result, arg_dict))
#
# File /nfs4/pyenv-dd902bed-4a1b-42c2-8824-a229cbc0d771/lib/python3.11/site-packages/sempy_labs/directlake/_update_directlake_partition_entity.py:217, in add_table_to_direct_lake_semantic_model(dataset, table_name, lakehouse_table_name, refresh, workspace, columns)
#     213 tom.add_table(name=table_name)
#     214 print(
#     215     f"{icons.green_dot} The '{table_name}' table has been added to the '{dataset_name}' semantic model within the '{workspace_name}' workspace."
#     216 )
# --> 217 tom.add_entity_partition(
#     218     table_name=table_name, entity_name=lakehouse_table_name
#     219 )
#     220 print(
#     221     f"{icons.green_dot} The '{lakehouse_table_name}' partition has been added to the '{table_name}' table in the '{dataset_name}' semantic model within the '{workspace_name}' workspace."
#     222 )
#     224 for _, r in dfLC_filt.iterrows():
#
# File /nfs4/pyenv-dd902bed-4a1b-42c2-8824-a229cbc0d771/lib/python3.11/site-packages/sempy_labs/tom/_model.py:1407, in TOMWrapper.add_entity_partition(self, table_name, entity_name, expression, description, schema_name)
#    1405 ep.EntityName = entity_name
#    1406 if expression is None:
# -> 1407     ep.ExpressionSource = self.model.Expressions["DatabaseQuery"]
#    1408 else:
#    1409     ep.ExpressionSource = self.model.Expressions[expression]
#
# ArgumentException: An object with name 'DatabaseQuery' does not exist in the collection. (Parameter 'name')
#    at Microsoft.AnalysisServices.Tabular.NamedMetadataObjectCollection`2.get_Item(String name)
