# %% [markdown]
# ## This notebook initializes a Semantic Model
# Resulting semantic model is still empty, tables and other objects are added based on notebooks that load tables to gold.

# %%
# %pip install semantic-link-labs
import sempy_labs as labs
# Out:
# StatementMeta(, f8cba8c6-c924-464d-9fa1-699060c78c92, 8, Finished, Available, Finished, False)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.4/973.4 kB 87.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 139.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.3/317.3 kB 76.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 18.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 91.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 34.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 61.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 12.0 MB/s eta 0:00:00
# ...

# %%
semanticmodel_name = "Live Demo Data Grillen"
# Out:
# StatementMeta(, f8cba8c6-c924-464d-9fa1-699060c78c92, 10, Finished, Available, Finished, False)

# %%
# labs.create_blank_semantic_model(
#     dataset=semanticmodel_name,
#     # compatibility_level=1605, # if not specified, defaults to 1605
#     workspace=None, # if not specified, will be the same workspace as the notebook runs
#     overwrite=True
# )
# Out:
# StatementMeta(, f8cba8c6-c924-464d-9fa1-699060c78c92, 12, Finished, Available, Finished, False)

# %%
# show input parameters
labs.create_blank_semantic_model
# Out:
# StatementMeta(, f8cba8c6-c924-464d-9fa1-699060c78c92, 13, Finished, Available, Finished, False)
# <function sempy_labs._generate_semantic_model.create_blank_semantic_model(dataset: str, compatibility_level: int = 1702, workspace: Union[str, uuid.UUID, NoneType] = None, overwrite: bool = True) -> uuid.UUID>

# %% [markdown]
# ## Measure table
# Given semantic models can only be created containing at least 1 table, we must have a placeholder table. We create the measure table here, which is a good practice.
#
# The name "Measures" is reserved.

# %%
# Create empty dataframe as measure table

from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType

# Define a schema with one column
schema = StructType([
    StructField("Message", StringType(), True)
])

# Create a DataFrame with one row and one column
data = [(" ",)]
df = spark.createDataFrame(data, schema=schema)

# Show the DataFrame (just to verify)
df.show()

# Save to LH_STORE_Gold (your default Lakehouse) as a new table
df.write.mode("overwrite").saveAsTable("_Measures")
# Out:
# StatementMeta(, f8cba8c6-c924-464d-9fa1-699060c78c92, 14, Finished, Available, Finished, False)
# +-------+
# |Message|
# +-------+
# |       |
# +-------+

# %% [markdown]
# ## Create semantic model

# %%
# Generate a Direct Lake semantic model from the _Measures table
# Key fix: the API expects the parameter name 'tables' instead of 'lakehouse_tables'.

labs.directlake.generate_direct_lake_semantic_model(
    dataset=semanticmodel_name,
    tables=["_measures"],  
    workspace=None,
    source='LH_STORE_Gold',
    source_type='Lakehouse',
    source_workspace=None,
    use_sql_endpoint=True,
    inherit_descriptions=False,
    refresh=False
)
# Out:
# StatementMeta(, f8cba8c6-c924-464d-9fa1-699060c78c92, 22, Finished, Available, Finished, False)
# 🟢 The 'Live Demo Data Grillen' semantic model was created within the 'Reaching maximum automation' workspace.
