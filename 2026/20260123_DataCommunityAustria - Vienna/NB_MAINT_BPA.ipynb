# %%
# Install sempy package
# %pip install semantic-link-labs
import sempy.fabric as fabric
import sempy_labs as labs
import sempy_labs.report as rep

# Load extension 
#%load_ext sempy
# Out:
# StatementMeta(, 2a5004d8-3d07-4e78-84ab-4e300b0ba7b3, 19, Finished, Available, Finished)
# Requirement already satisfied: semantic-link-labs in /nfs4/pyenv-331ae63c-a626-43e2-a13c-0546400d90b9/lib/python3.10/site-packages (0.9.4)
# Requirement already satisfied: semantic-link-sempy>=0.8.5 in /nfs4/pyenv-331ae63c-a626-43e2-a13c-0546400d90b9/lib/python3.10/site-packages (from semantic-link-labs) (0.9.3)
# Requirement already satisfied: anytree in /nfs4/pyenv-331ae63c-a626-43e2-a13c-0546400d90b9/lib/python3.10/site-packages (from semantic-link-labs) (2.12.1)
# Requirement already satisfied: powerbiclient in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-labs) (3.1.1)
# Requirement already satisfied: polib in /nfs4/pyenv-331ae63c-a626-43e2-a13c-0546400d90b9/lib/python3.10/site-packages (from semantic-link-labs) (1.2.0)
# Requirement already satisfied: jsonpath_ng in /nfs4/pyenv-331ae63c-a626-43e2-a13c-0546400d90b9/lib/python3.10/site-packages (from semantic-link-labs) (1.7.0)
# Requirement already satisfied: clr-loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (0.2.6)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (0.20.1)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (12.0.1)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (1.3.0)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (4.66.1)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.8.5->semantic-link-labs) (13.6.0)
# Requirement already satisfied: six in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from anytree->semantic-link-labs) (1.16.0)
# Requirement already satisfied: ply in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jsonpath_ng->semantic-link-labs) (3.11)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (8.0.7)
# Requirement already satisfied: jupyter-ui-poll>=0.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (0.2.2)
# Requirement already satisfied: msal>=1.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (1.24.1)
# Requirement already satisfied: requests>=2.25.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (2.31.0)
# Requirement already satisfied: pandas in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (2.0.3)
# Requirement already satisfied: pyspark in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (3.4.1.5.3.20230713)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from clr-loader>=0.2.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (1.16.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (6.26.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (8.14.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.12.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.9)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from msal>=1.8.0->powerbiclient->semantic-link-labs) (2.8.0)
# Requirement already satisfied: cryptography<44,>=0.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from msal>=1.8.0->powerbiclient->semantic-link-labs) (41.0.5)
# Requirement already satisfied: numpy>=1.16.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pyarrow>=12.0.1->semantic-link-sempy>=0.8.5->semantic-link-labs) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (1.26.17)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (2.16.1)
# Requirement already satisfied: scipy>=1.5.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.8.5->semantic-link-labs) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.8.5->semantic-link-labs) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.8.5->semantic-link-labs) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas->powerbiclient->semantic-link-labs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas->powerbiclient->semantic-link-labs) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas->powerbiclient->semantic-link-labs) (2023.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pyspark->powerbiclient->semantic-link-labs) (0.10.9.7)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from cffi>=1.13->clr-loader>=0.2.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (2.21)
# Requirement already satisfied: comm>=0.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (8.5.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (1.5.8)
# Requirement already satisfied: packaging in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (23.2)
# Requirement already satisfied: psutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (6.3.3)
# Requirement already satisfied: backcall in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.0)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.19.1)
# Requirement already satisfied: pickleshare in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.39)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.8.0)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.3.5->semantic-link-sempy>=0.8.5->semantic-link-labs) (0.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.8)
# Requirement already satisfied: executing>=1.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (2.4.0)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.2)
#
# [notice] A new release of pip is available: 23.1.2 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %% [markdown]
# ### Run BPA on 1 specific model

# %%
# Define variables
_SemanticModelName = "AW2020IncrementalCompleted"
_workspace = "Semantic Link for Power BI folks"
# Out:
# StatementMeta(, 2a5004d8-3d07-4e78-84ab-4e300b0ba7b3, 21, Finished, Available, Finished)

# %%
# show rules
rules = labs.model_bpa_rules()
rules.head(5)
# Out:
# StatementMeta(, 2a5004d8-3d07-4e78-84ab-4e300b0ba7b3, 25, Finished, Available, Finished)
#       Category               Scope Severity  \
# 0  Performance              Column  Warning
# 1  Performance              Column  Warning
# 2  Performance        Relationship  Warning
# 3  Performance  Row Level Security     Info
# 4  Performance               Table  Warning
#
#                                                                               Rule Name  \
# 0                                                  Do not use floating point data types
# 1                                                        Avoid using calculated columns
# 2                      Check if bi-directional and many-to-many relationships are valid
# 3                                Check if dynamic row level security (RLS) is necessary
# 4  Avoid using many-to-many relationships on tables used for dynamic row level security
#
#                                                        Expression  \
# 0  <function model_bpa_rules.<locals>.<lambda> at 0x75f1d30e9480>
# 1  <function model_bpa_rules.<locals>.<lambda> at 0x75f1d30e8670>
# 2  <function model_bpa_rules.<locals>.<lambda> at 0x75f1d30e8ee0>
# 3  <function model_bpa_rules.<locals>.<lambda> at 0x75f1d30e8b80>
# 4  <function model_bpa_rules.<locals>.<lambda> at 0x75f1d30e8af0>
#
#                                                                                            Description  \
# 0  The "Double" floating point data type should be avoided, as it can result in unpredictable round...
# 1  Calculated columns do not compress as well as data columns so they take up more memory. They als...
# 2  Bi-directional and many-to-many relationships may cause performance degradation or even have uni...
# 3  Usage of dynamic row level security (RLS) can add memory and performance overhead. Please resear...
# 4  Using many-to-many relationships on tables which use dynamic row level security can cause seriou...
#
#                                                                                URL
# 0                                                                             None
# 1                                https://www.elegantbi.com/post/top10bestpractices
# 2  https://www.sqlbi.com/articles/bidirectional-relationships-and-ambiguity-in-dax
# 3                      https://docs.microsoft.com/power-bi/admin/service-admin-rls
# 4                                https://www.elegantbi.com/post/dynamicrlspatterns

# %%
labs.run_model_bpa(
    workspace= _workspace,
    dataset= _SemanticModelName 
)
# Out:
# StatementMeta(, 2a5004d8-3d07-4e78-84ab-4e300b0ba7b3, 22, Finished, Available, Finished)
#     <style>
#         .tab { overflow: hidden; border: 1px solid #ccc; background-color: #f1f1f1; }
#         .tab button { background-color: inherit; float: left; border: none; outline: none; cursor: pointer; padding: 14px 16px; transition: 0.3s; }
#         .tab button:hover { background-color: #ddd; }
#         .tab button.active { background-color: #ccc; }
#         .tabcontent { display: none; padding: 6px 12px; border: 1px solid #ccc; border-top: none; }
#         .tabcontent.active { display: block; }
#         .tooltip { position: relative; display: inline-block; }
#         .tooltip .tooltiptext { visibility: hidden; width: 300px; background-color: #555; color: #fff; text-align: center; border-radius: 6px; padding: 5px; position: absolute; z-index: 1; bottom: 125%; left: 50%; margin-left: -110px; opacity: 0; transition: opacity 0.3s; }
#         .tooltip:hover .tooltiptext { visibility: visible; opacity: 1; }
#     </style>
#     <div class="tab"><button class="tablinks active" onclick="openTab(event, 'tab0')"><b>DAX Expressions</b><br/>⚠️ (2)</button><button class="tablinks " onclick="openTab(event, 'tab1')"><b>Formatting</b><br/>⚠️ (31) + ℹ️ (18)</button><button class="tablinks " onclick="openTab(event, 'tab2')"><b>Maintenance</b><br/>ℹ️ (133)</button><button class="tablinks " onclick="openTab(event, 'tab3')"><b>Performance</b><br/>⚠️ (5)</button></div><div id="tab0" class="tabcontent active"><table border="1"><tr><th>Rule Name</th><th>Object Type</th><th>Object Name</th><th>Severity</th></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://dax.guide/userelationship">Inactive relationships that are never activated</a><span class="tooltiptext">Inactive relationships are activated using the USERELATIONSHIP function. If an inactive relationship is not referenced in any measure via this function, the relationship will not be used. It should be determined whether the relationship is not necessary or to activate the relationship via this method.</span></td><td>Relationship</td><td>'FactInternetSales'[DueDateKey] -> 'DimDate'[DateKey]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://dax.guide/userelationship">Inactive relationships that are never activated</a><span class="tooltiptext">Inactive relationships are activated using the USERELATIONSHIP function. If an inactive relationship is not referenced in any measure via this function, the relationship will not be used. It should be determined whether the relationship is not necessary or to activate the relationship via this method.</span></td><td>Relationship</td><td>'FactInternetSales'[ShipDateKey] -> 'DimDate'[DateKey]</td><td style="text-align: center;">⚠️</td></tr></table></div><div id="tab1" class="tabcontent "><table border="1"><tr><th>Rule Name</th><th>Object Type</th><th>Object Name</th><th>Severity</th></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'DimProduct'[DaysToManufacture]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'DimProduct'[DealerPrice]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'DimProduct'[ListPrice]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'DimProduct'[ReorderPoint]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'DimProduct'[SafetyStockLevel]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmous ...

# %% [markdown]
# ### Run BPA in bulk
# Saves results to connected lakehouse

# %%
labs.run_model_bpa_bulk(
    workspace= _workspace
)
# Out:
# StatementMeta(, 9f2e8ffc-804c-4880-801d-4a7b7065d8ed, 13, Finished, Available, Finished)
# ⌛ Collecting Model BPA stats for the 'Example Semantic Model' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 Collected Model BPA stats for the 'Example Semantic Model' semantic model within the 'Semantic Link for Power BI folks' workspace.
# ⌛ Collecting Model BPA stats for the 'ModelDocumentation' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 Collected Model BPA stats for the 'ModelDocumentation' semantic model within the 'Semantic Link for Power BI folks' workspace.
# ⌛ Collecting Model BPA stats for the 'AW2020IncrementalCompleted' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 Collected Model BPA stats for the 'AW2020IncrementalCompleted' semantic model within the 'Semantic Link for Power BI folks' workspace.
# ⌛ Collecting Model BPA stats for the 'IncrementalRefreshPartitioning' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 Collected Model BPA stats for the 'IncrementalRefreshPartitioning' semantic model within the 'Semantic Link for Power BI folks' workspace.
# ⌛ Saving the Model BPA results of the 'Semantic Link for Power BI folks' workspace to the 'modelbparesults' within the 'LH_STORE_BPA' lakehouse within the 'Semantic Link for Power BI folks' workspace...
# 🟢 The dataframe has been saved as the 'modelbparesults' table in the 'LH_STORE_BPA' lakehouse within the 'Semantic Link for Power BI folks' workspace.
# 🟢 Saved BPA results to the 'modelbparesults' delta table.
# 🟢 Bulk BPA scan complete.

# %% [markdown]
# ### Create report
# visualize the BPA outputs

# %%
# create semantic model
# uses the lakehouse specified as default to this lakehouse
labs.create_model_bpa_semantic_model()

# create report
rep.create_model_bpa_report()
# Out:
# StatementMeta(, 9f2e8ffc-804c-4880-801d-4a7b7065d8ed, 14, Finished, Available, Finished)
# 🟢 The 'ModelBPA' semantic model was created within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'BPAResults' table has been added to the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'modelbparesults' partition has been added to the 'BPAResults' table in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Capacity_Name' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Capacity_Id' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Workspace_Name' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Workspace_Id' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Dataset_Name' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Dataset_Id' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Configured_By' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Rule_Name' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Category' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Severity' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Object_Type' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Object_Name' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Description' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'URL' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'RunId' column has been added to the 'BPAResults' table as a 'Int64' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# 🟢 The 'Timestamp' column has been added to the 'BPAResults' table as a 'DateTime' data type in the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace.
# ⌛ Refresh of the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace is in progress...
# 🟢 Refresh 'full' of the 'ModelBPA' semantic model within the 'Semantic Link for Power BI folks' workspace is complete.
# 🟢 The 'ModelBPA' report within the 'Semantic Link for Power BI folks' workspace has been successfully updated.
